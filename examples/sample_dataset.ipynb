# %%
from scipy.constants import micro, milli

# define the initial conditions and kinetics data
initial_conc = {
    'Acetyl phosphate': 0.1,
    'ADP': 0.3
}

kinetics_data = {
  "acetate kinase": {
    "ATP + Acetate = ADP + Acetyl phosphate": {
        'condition_1': {
            "Parameters": {
              "B": {
                "species": "Acetyl phosphate",
                "value": "0.8",
                "comment": "mM"
              },
              "A": {
                "species": "ADP",
                "value": "1.0",
                "comment": "mM"
              }
            },
            "SubstitutedRateLaw": "(68.0/milli*A*B)/(50.0*micro*0.34*micro+360.0*micro*B+0.34*micro*A+A*B)",
            "PubMedID": "4362687.0",
            "Publication": "Janson CA, Cleland WW: The inhibition of acetate, pyruvate, and 3-phosphogylcerate kinases by chromium adenosine triphosphate, J Biol Chem 1974 (249) , 2567-71",
            "pH": "7.0",
            "Temperature": "25.0",
            "Organism": "Escherichia coli",
            "SabioReactionID": 71
        }
    },
  }
}


# define inital conditions
total_minutes = 200
timestep = 2 
temp_c = 25
ph = 7

# %%
import cobra
# %run ../dfbapy/dfba.py



# initiate the dFBA object
dfba = dFBA('e_coli_core.xml',  kinetics_data, verbose = False, printing = True)
dfba.simulate(initial_conc, total_minutes, timestep, temp_c, ph)
# Out:
#                2 (min) 4 (min) 6 (min) 8 (min) 10 (min) 12 (min) 14 (min)  \
# enzymes
# acetate kinase     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#                16 (min) 18 (min) 20 (min)  ... 182 (min) 184 (min) 186 (min)  \
# enzymes                                    ...
# acetate kinase      NaN      NaN      NaN  ...       NaN       NaN       NaN
#
#                188 (min) 190 (min) 192 (min) 194 (min) 196 (min) 198 (min)  \
# enzymes
# acetate kinase       NaN       NaN       NaN       NaN       NaN       NaN
#
#                200 (min)
# enzymes
# acetate kinase       NaN
#
# [1 rows x 100 columns]
# timestep 1
#
# objective value for timestep 1:  0.8739215069684301
#
#
# timestep 2
#
# objective value for timestep 2:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 2
# --> The D-Lactate concentration did not change in timestep 2
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 2
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 2
# --> The Acetate concentration did not change in timestep 2
# --> The Pyruvate concentration did not change in timestep 2
# --> The Acetaldehyde concentration did not change in timestep 2
# --> The Acetyl-CoA concentration did not change in timestep 2
# --> The Succinate concentration did not change in timestep 2
# --> The Acetyl phosphate concentration did not change in timestep 2
# --> The 2-Oxoglutarate concentration did not change in timestep 2
# --> The AMP C10H12N5O7P concentration did not change in timestep 2
# --> The Coenzyme A concentration did not change in timestep 2
# --> The Ethanol concentration did not change in timestep 2
# --> The Formate concentration did not change in timestep 2
# --> The D-Fructose concentration did not change in timestep 2
# timestep 3
#
# objective value for timestep 3:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 3
# --> The D-Lactate concentration did not change in timestep 3
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 3
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 3
# --> The Acetate concentration did not change in timestep 3
# --> The Pyruvate concentration did not change in timestep 3
# --> The Acetaldehyde concentration did not change in timestep 3
# --> The Acetyl-CoA concentration did not change in timestep 3
# --> The Succinate concentration did not change in timestep 3
# --> The Acetyl phosphate concentration did not change in timestep 3
# --> The 2-Oxoglutarate concentration did not change in timestep 3
# --> The AMP C10H12N5O7P concentration did not change in timestep 3
# --> The Coenzyme A concentration did not change in timestep 3
# --> The Ethanol concentration did not change in timestep 3
# --> The Formate concentration did not change in timestep 3
# --> The D-Fructose concentration did not change in timestep 3
# timestep 4
#
# objective value for timestep 4:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 4
# --> The D-Lactate concentration did not change in timestep 4
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 4
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 4
# --> The Acetate concentration did not change in timestep 4
# --> The Pyruvate concentration did not change in timestep 4
# --> The Acetaldehyde concentration did not change in timestep 4
# --> The Acetyl-CoA concentration did not change in timestep 4
# --> The Succinate concentration did not change in timestep 4
# --> The Acetyl phosphate concentration did not change in timestep 4
# --> The 2-Oxoglutarate concentration did not change in timestep 4
# --> The AMP C10H12N5O7P concentration did not change in timestep 4
# --> The Coenzyme A concentration did not change in timestep 4
# --> The Ethanol concentration did not change in timestep 4
# --> The Formate concentration did not change in timestep 4
# --> The D-Fructose concentration did not change in timestep 4
# timestep 5
#
# objective value for timestep 5:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 5
# --> The D-Lactate concentration did not change in timestep 5
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 5
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 5
# --> The Acetate concentration did not change in timestep 5
# --> The Pyruvate concentration did not change in timestep 5
# --> The Acetaldehyde concentration did not change in timestep 5
# --> The Acetyl-CoA concentration did not change in timestep 5
# --> The Succinate concentration did not change in timestep 5
# --> The Acetyl phosphate concentration did not change in timestep 5
# --> The 2-Oxoglutarate concentration did not change in timestep 5
# --> The AMP C10H12N5O7P concentration did not change in timestep 5
# --> The Coenzyme A concentration did not change in timestep 5
# --> The Ethanol concentration did not change in timestep 5
# --> The Formate concentration did not change in timestep 5
# --> The D-Fructose concentration did not change in timestep 5
# timestep 6
#
# objective value for timestep 6:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 6
# --> The D-Lactate concentration did not change in timestep 6
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 6
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 6
# --> The Acetate concentration did not change in timestep 6
# --> The Pyruvate concentration did not change in timestep 6
# --> The Acetaldehyde concentration did not change in timestep 6
# --> The Acetyl-CoA concentration did not change in timestep 6
# --> The Succinate concentration did not change in timestep 6
# --> The Acetyl phosphate concentration did not change in timestep 6
# --> The 2-Oxoglutarate concentration did not change in timestep 6
# --> The AMP C10H12N5O7P concentration did not change in timestep 6
# --> The Coenzyme A concentration did not change in timestep 6
# --> The Ethanol concentration did not change in timestep 6
# --> The Formate concentration did not change in timestep 6
# --> The D-Fructose concentration did not change in timestep 6
# timestep 7
#
# objective value for timestep 7:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 7
# --> The D-Lactate concentration did not change in timestep 7
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 7
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 7
# --> The Acetate concentration did not change in timestep 7
# --> The Pyruvate concentration did not change in timestep 7
# --> The Acetaldehyde concentration did not change in timestep 7
# --> The Acetyl-CoA concentration did not change in timestep 7
# --> The Succinate concentration did not change in timestep 7
# --> The Acetyl phosphate concentration did not change in timestep 7
# --> The 2-Oxoglutarate concentration did not change in timestep 7
# --> The AMP C10H12N5O7P concentration did not change in timestep 7
# --> The Coenzyme A concentration did not change in timestep 7
# --> The Ethanol concentration did not change in timestep 7
# --> The Formate concentration did not change in timestep 7
# --> The D-Fructose concentration did not change in timestep 7
# timestep 8
#
# objective value for timestep 8:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 8
# --> The D-Lactate concentration did not change in timestep 8
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 8
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 8
# --> The Acetate concentration did not change in timestep 8
# --> The Pyruvate concentration did not change in timestep 8
# --> The Acetaldehyde concentration did not change in timestep 8
# --> The Acetyl-CoA concentration did not change in timestep 8
# --> The Succinate concentration did not change in timestep 8
# --> The Acetyl phosphate concentration did not change in timestep 8
# --> The 2-Oxoglutarate concentration did not change in timestep 8
# --> The AMP C10H12N5O7P concentration did not change in timestep 8
# --> The Coenzyme A concentration did not change in timestep 8
# --> The Ethanol concentration did not change in timestep 8
# --> The Formate concentration did not change in timestep 8
# --> The D-Fructose concentration did not change in timestep 8
# timestep 9
#
# objective value for timestep 9:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 9
# --> The D-Lactate concentration did not change in timestep 9
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 9
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 9
# --> The Acetate concentration did not change in timestep 9
# --> The Pyruvate concentration did not change in timestep 9
# --> The Acetaldehyde concentration did not change in timestep 9
# --> The Acetyl-CoA concentration did not change in timestep 9
# --> The Succinate concentration did not change in timestep 9
# --> The Acetyl phosphate concentration did not change in timestep 9
# --> The 2-Oxoglutarate concentration did not change in timestep 9
# --> The AMP C10H12N5O7P concentration did not change in timestep 9
# --> The Coenzyme A concentration did not change in timestep 9
# --> The Ethanol concentration did not change in timestep 9
# --> The Formate concentration did not change in timestep 9
# --> The D-Fructose concentration did not change in timestep 9
# timestep 10
#
# objective value for timestep 10:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 10
# --> The D-Lactate concentration did not change in timestep 10
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 10
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 10
# --> The Acetate concentration did not change in timestep 10
# --> The Pyruvate concentration did not change in timestep 10
# --> The Acetaldehyde concentration did not change in timestep 10
# --> The Acetyl-CoA concentration did not change in timestep 10
# --> The Succinate concentration did not change in timestep 10
# --> The Acetyl phosphate concentration did not change in timestep 10
# --> The 2-Oxoglutarate concentration did not change in timestep 10
# --> The AMP C10H12N5O7P concentration did not change in timestep 10
# --> The Coenzyme A concentration did not change in timestep 10
# --> The Ethanol concentration did not change in timestep 10
# --> The Formate concentration did not change in timestep 10
# --> The D-Fructose concentration did not change in timestep 10
# timestep 11
#
# objective value for timestep 11:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 11
# --> The D-Lactate concentration did not change in timestep 11
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 11
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 11
# --> The Acetate concentration did not change in timestep 11
# --> The Pyruvate concentration did not change in timestep 11
# --> The Acetaldehyde concentration did not change in timestep 11
# --> The Acetyl-CoA concentration did not change in timestep 11
# --> The Succinate concentration did not change in timestep 11
# --> The Acetyl phosphate concentration did not change in timestep 11
# --> The 2-Oxoglutarate concentration did not change in timestep 11
# --> The AMP C10H12N5O7P concentration did not change in timestep 11
# --> The Coenzyme A concentration did not change in timestep 11
# --> The Ethanol concentration did not change in timestep 11
# --> The Formate concentration did not change in timestep 11
# --> The D-Fructose concentration did not change in timestep 11
# timestep 12
#
# objective value for timestep 12:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 12
# --> The D-Lactate concentration did not change in timestep 12
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 12
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 12
# --> The Acetate concentration did not change in timestep 12
# --> The Pyruvate concentration did not change in timestep 12
# --> The Acetaldehyde concentration did not change in timestep 12
# --> The Acetyl-CoA concentration did not change in timestep 12
# --> The Succinate concentration did not change in timestep 12
# --> The Acetyl phosphate concentration did not change in timestep 12
# --> The 2-Oxoglutarate concentration did not change in timestep 12
# --> The AMP C10H12N5O7P concentration did not change in timestep 12
# --> The Coenzyme A concentration did not change in timestep 12
# --> The Ethanol concentration did not change in timestep 12
# --> The Formate concentration did not change in timestep 12
# --> The D-Fructose concentration did not change in timestep 12
# timestep 13
#
# objective value for timestep 13:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 13
# --> The D-Lactate concentration did not change in timestep 13
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 13
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 13
# --> The Acetate concentration did not change in timestep 13
# --> The Pyruvate concentration did not change in timestep 13
# --> The Acetaldehyde concentration did not change in timestep 13
# --> The Acetyl-CoA concentration did not change in timestep 13
# --> The Succinate concentration did not change in timestep 13
# --> The Acetyl phosphate concentration did not change in timestep 13
# --> The 2-Oxoglutarate concentration did not change in timestep 13
# --> The AMP C10H12N5O7P concentration did not change in timestep 13
# --> The Coenzyme A concentration did not change in timestep 13
# --> The Ethanol concentration did not change in timestep 13
# --> The Formate concentration did not change in timestep 13
# --> The D-Fructose concentration did not change in timestep 13
# timestep 14
#
# objective value for timestep 14:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 14
# --> The D-Lactate concentration did not change in timestep 14
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 14
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 14
# --> The Acetate concentration did not change in timestep 14
# --> The Pyruvate concentration did not change in timestep 14
# --> The Acetaldehyde concentration did not change in timestep 14
# --> The Acetyl-CoA concentration did not change in timestep 14
# --> The Succinate concentration did not change in timestep 14
# --> The Acetyl phosphate concentration did not change in timestep 14
# --> The 2-Oxoglutarate concentration did not change in timestep 14
# --> The AMP C10H12N5O7P concentration did not change in timestep 14
# --> The Coenzyme A concentration did not change in timestep 14
# --> The Ethanol concentration did not change in timestep 14
# --> The Formate concentration did not change in timestep 14
# --> The D-Fructose concentration did not change in timestep 14
# timestep 15
#
# objective value for timestep 15:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 15
# --> The D-Lactate concentration did not change in timestep 15
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 15
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 15
# --> The Acetate concentration did not change in timestep 15
# --> The Pyruvate concentration did not change in timestep 15
# --> The Acetaldehyde concentration did not change in timestep 15
# --> The Acetyl-CoA concentration did not change in timestep 15
# --> The Succinate concentration did not change in timestep 15
# --> The Acetyl phosphate concentration did not change in timestep 15
# --> The 2-Oxoglutarate concentration did not change in timestep 15
# --> The AMP C10H12N5O7P concentration did not change in timestep 15
# --> The Coenzyme A concentration did not change in timestep 15
# --> The Ethanol concentration did not change in timestep 15
# --> The Formate concentration did not change in timestep 15
# --> The D-Fructose concentration did not change in timestep 15
# timestep 16
#
# objective value for timestep 16:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 16
# --> The D-Lactate concentration did not change in timestep 16
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 16
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 16
# --> The Acetate concentration did not change in timestep 16
# --> The Pyruvate concentration did not change in timestep 16
# --> The Acetaldehyde concentration did not change in timestep 16
# --> The Acetyl-CoA concentration did not change in timestep 16
# --> The Succinate concentration did not change in timestep 16
# --> The Acetyl phosphate concentration did not change in timestep 16
# --> The 2-Oxoglutarate concentration did not change in timestep 16
# --> The AMP C10H12N5O7P concentration did not change in timestep 16
# --> The Coenzyme A concentration did not change in timestep 16
# --> The Ethanol concentration did not change in timestep 16
# --> The Formate concentration did not change in timestep 16
# --> The D-Fructose concentration did not change in timestep 16
# timestep 17
#
# objective value for timestep 17:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 17
# --> The D-Lactate concentration did not change in timestep 17
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 17
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 17
# --> The Acetate concentration did not change in timestep 17
# --> The Pyruvate concentration did not change in timestep 17
# --> The Acetaldehyde concentration did not change in timestep 17
# --> The Acetyl-CoA concentration did not change in timestep 17
# --> The Succinate concentration did not change in timestep 17
# --> The Acetyl phosphate concentration did not change in timestep 17
# --> The 2-Oxoglutarate concentration did not change in timestep 17
# --> The AMP C10H12N5O7P concentration did not change in timestep 17
# --> The Coenzyme A concentration did not change in timestep 17
# --> The Ethanol concentration did not change in timestep 17
# --> The Formate concentration did not change in timestep 17
# --> The D-Fructose concentration did not change in timestep 17
# timestep 18
#
# objective value for timestep 18:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 18
# --> The D-Lactate concentration did not change in timestep 18
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 18
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 18
# --> The Acetate concentration did not change in timestep 18
# --> The Pyruvate concentration did not change in timestep 18
# --> The Acetaldehyde concentration did not change in timestep 18
# --> The Acetyl-CoA concentration did not change in timestep 18
# --> The Succinate concentration did not change in timestep 18
# --> The Acetyl phosphate concentration did not change in timestep 18
# --> The 2-Oxoglutarate concentration did not change in timestep 18
# --> The AMP C10H12N5O7P concentration did not change in timestep 18
# --> The Coenzyme A concentration did not change in timestep 18
# --> The Ethanol concentration did not change in timestep 18
# --> The Formate concentration did not change in timestep 18
# --> The D-Fructose concentration did not change in timestep 18
# timestep 19
#
# objective value for timestep 19:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 19
# --> The D-Lactate concentration did not change in timestep 19
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 19
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 19
# --> The Acetate concentration did not change in timestep 19
# --> The Pyruvate concentration did not change in timestep 19
# --> The Acetaldehyde concentration did not change in timestep 19
# --> The Acetyl-CoA concentration did not change in timestep 19
# --> The Succinate concentration did not change in timestep 19
# --> The Acetyl phosphate concentration did not change in timestep 19
# --> The 2-Oxoglutarate concentration did not change in timestep 19
# --> The AMP C10H12N5O7P concentration did not change in timestep 19
# --> The Coenzyme A concentration did not change in timestep 19
# --> The Ethanol concentration did not change in timestep 19
# --> The Formate concentration did not change in timestep 19
# --> The D-Fructose concentration did not change in timestep 19
# timestep 20
#
# objective value for timestep 20:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 20
# --> The D-Lactate concentration did not change in timestep 20
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 20
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 20
# --> The Acetate concentration did not change in timestep 20
# --> The Pyruvate concentration did not change in timestep 20
# --> The Acetaldehyde concentration did not change in timestep 20
# --> The Acetyl-CoA concentration did not change in timestep 20
# --> The Succinate concentration did not change in timestep 20
# --> The Acetyl phosphate concentration did not change in timestep 20
# --> The 2-Oxoglutarate concentration did not change in timestep 20
# --> The AMP C10H12N5O7P concentration did not change in timestep 20
# --> The Coenzyme A concentration did not change in timestep 20
# --> The Ethanol concentration did not change in timestep 20
# --> The Formate concentration did not change in timestep 20
# --> The D-Fructose concentration did not change in timestep 20
# timestep 21
#
# objective value for timestep 21:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 21
# --> The D-Lactate concentration did not change in timestep 21
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 21
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 21
# --> The Acetate concentration did not change in timestep 21
# --> The Pyruvate concentration did not change in timestep 21
# --> The Acetaldehyde concentration did not change in timestep 21
# --> The Acetyl-CoA concentration did not change in timestep 21
# --> The Succinate concentration did not change in timestep 21
# --> The Acetyl phosphate concentration did not change in timestep 21
# --> The 2-Oxoglutarate concentration did not change in timestep 21
# --> The AMP C10H12N5O7P concentration did not change in timestep 21
# --> The Coenzyme A concentration did not change in timestep 21
# --> The Ethanol concentration did not change in timestep 21
# --> The Formate concentration did not change in timestep 21
# --> The D-Fructose concentration did not change in timestep 21
# timestep 22
#
# objective value for timestep 22:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 22
# --> The D-Lactate concentration did not change in timestep 22
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 22
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 22
# --> The Acetate concentration did not change in timestep 22
# --> The Pyruvate concentration did not change in timestep 22
# --> The Acetaldehyde concentration did not change in timestep 22
# --> The Acetyl-CoA concentration did not change in timestep 22
# --> The Succinate concentration did not change in timestep 22
# --> The Acetyl phosphate concentration did not change in timestep 22
# --> The 2-Oxoglutarate concentration did not change in timestep 22
# --> The AMP C10H12N5O7P concentration did not change in timestep 22
# --> The Coenzyme A concentration did not change in timestep 22
# --> The Ethanol concentration did not change in timestep 22
# --> The Formate concentration did not change in timestep 22
# --> The D-Fructose concentration did not change in timestep 22
# timestep 23
#
# objective value for timestep 23:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 23
# --> The D-Lactate concentration did not change in timestep 23
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 23
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 23
# --> The Acetate concentration did not change in timestep 23
# --> The Pyruvate concentration did not change in timestep 23
# --> The Acetaldehyde concentration did not change in timestep 23
# --> The Acetyl-CoA concentration did not change in timestep 23
# --> The Succinate concentration did not change in timestep 23
# --> The Acetyl phosphate concentration did not change in timestep 23
# --> The 2-Oxoglutarate concentration did not change in timestep 23
# --> The AMP C10H12N5O7P concentration did not change in timestep 23
# --> The Coenzyme A concentration did not change in timestep 23
# --> The Ethanol concentration did not change in timestep 23
# --> The Formate concentration did not change in timestep 23
# --> The D-Fructose concentration did not change in timestep 23
# timestep 24
#
# objective value for timestep 24:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 24
# --> The D-Lactate concentration did not change in timestep 24
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 24
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 24
# --> The Acetate concentration did not change in timestep 24
# --> The Pyruvate concentration did not change in timestep 24
# --> The Acetaldehyde concentration did not change in timestep 24
# --> The Acetyl-CoA concentration did not change in timestep 24
# --> The Succinate concentration did not change in timestep 24
# --> The Acetyl phosphate concentration did not change in timestep 24
# --> The 2-Oxoglutarate concentration did not change in timestep 24
# --> The AMP C10H12N5O7P concentration did not change in timestep 24
# --> The Coenzyme A concentration did not change in timestep 24
# --> The Ethanol concentration did not change in timestep 24
# --> The Formate concentration did not change in timestep 24
# --> The D-Fructose concentration did not change in timestep 24
# timestep 25
#
# objective value for timestep 25:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 25
# --> The D-Lactate concentration did not change in timestep 25
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 25
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 25
# --> The Acetate concentration did not change in timestep 25
# --> The Pyruvate concentration did not change in timestep 25
# --> The Acetaldehyde concentration did not change in timestep 25
# --> The Acetyl-CoA concentration did not change in timestep 25
# --> The Succinate concentration did not change in timestep 25
# --> The Acetyl phosphate concentration did not change in timestep 25
# --> The 2-Oxoglutarate concentration did not change in timestep 25
# --> The AMP C10H12N5O7P concentration did not change in timestep 25
# --> The Coenzyme A concentration did not change in timestep 25
# --> The Ethanol concentration did not change in timestep 25
# --> The Formate concentration did not change in timestep 25
# --> The D-Fructose concentration did not change in timestep 25
# timestep 26
#
# objective value for timestep 26:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 26
# --> The D-Lactate concentration did not change in timestep 26
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 26
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 26
# --> The Acetate concentration did not change in timestep 26
# --> The Pyruvate concentration did not change in timestep 26
# --> The Acetaldehyde concentration did not change in timestep 26
# --> The Acetyl-CoA concentration did not change in timestep 26
# --> The Succinate concentration did not change in timestep 26
# --> The Acetyl phosphate concentration did not change in timestep 26
# --> The 2-Oxoglutarate concentration did not change in timestep 26
# --> The AMP C10H12N5O7P concentration did not change in timestep 26
# --> The Coenzyme A concentration did not change in timestep 26
# --> The Ethanol concentration did not change in timestep 26
# --> The Formate concentration did not change in timestep 26
# --> The D-Fructose concentration did not change in timestep 26
# timestep 27
#
# objective value for timestep 27:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 27
# --> The D-Lactate concentration did not change in timestep 27
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 27
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 27
# --> The Acetate concentration did not change in timestep 27
# --> The Pyruvate concentration did not change in timestep 27
# --> The Acetaldehyde concentration did not change in timestep 27
# --> The Acetyl-CoA concentration did not change in timestep 27
# --> The Succinate concentration did not change in timestep 27
# --> The Acetyl phosphate concentration did not change in timestep 27
# --> The 2-Oxoglutarate concentration did not change in timestep 27
# --> The AMP C10H12N5O7P concentration did not change in timestep 27
# --> The Coenzyme A concentration did not change in timestep 27
# --> The Ethanol concentration did not change in timestep 27
# --> The Formate concentration did not change in timestep 27
# --> The D-Fructose concentration did not change in timestep 27
# timestep 28
#
# objective value for timestep 28:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 28
# --> The D-Lactate concentration did not change in timestep 28
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 28
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 28
# --> The Acetate concentration did not change in timestep 28
# --> The Pyruvate concentration did not change in timestep 28
# --> The Acetaldehyde concentration did not change in timestep 28
# --> The Acetyl-CoA concentration did not change in timestep 28
# --> The Succinate concentration did not change in timestep 28
# --> The Acetyl phosphate concentration did not change in timestep 28
# --> The 2-Oxoglutarate concentration did not change in timestep 28
# --> The AMP C10H12N5O7P concentration did not change in timestep 28
# --> The Coenzyme A concentration did not change in timestep 28
# --> The Ethanol concentration did not change in timestep 28
# --> The Formate concentration did not change in timestep 28
# --> The D-Fructose concentration did not change in timestep 28
# timestep 29
#
# objective value for timestep 29:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 29
# --> The D-Lactate concentration did not change in timestep 29
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 29
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 29
# --> The Acetate concentration did not change in timestep 29
# --> The Pyruvate concentration did not change in timestep 29
# --> The Acetaldehyde concentration did not change in timestep 29
# --> The Acetyl-CoA concentration did not change in timestep 29
# --> The Succinate concentration did not change in timestep 29
# --> The Acetyl phosphate concentration did not change in timestep 29
# --> The 2-Oxoglutarate concentration did not change in timestep 29
# --> The AMP C10H12N5O7P concentration did not change in timestep 29
# --> The Coenzyme A concentration did not change in timestep 29
# --> The Ethanol concentration did not change in timestep 29
# --> The Formate concentration did not change in timestep 29
# --> The D-Fructose concentration did not change in timestep 29
# timestep 30
#
# objective value for timestep 30:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 30
# --> The D-Lactate concentration did not change in timestep 30
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 30
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 30
# --> The Acetate concentration did not change in timestep 30
# --> The Pyruvate concentration did not change in timestep 30
# --> The Acetaldehyde concentration did not change in timestep 30
# --> The Acetyl-CoA concentration did not change in timestep 30
# --> The Succinate concentration did not change in timestep 30
# --> The Acetyl phosphate concentration did not change in timestep 30
# --> The 2-Oxoglutarate concentration did not change in timestep 30
# --> The AMP C10H12N5O7P concentration did not change in timestep 30
# --> The Coenzyme A concentration did not change in timestep 30
# --> The Ethanol concentration did not change in timestep 30
# --> The Formate concentration did not change in timestep 30
# --> The D-Fructose concentration did not change in timestep 30
# timestep 31
#
# objective value for timestep 31:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 31
# --> The D-Lactate concentration did not change in timestep 31
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 31
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 31
# --> The Acetate concentration did not change in timestep 31
# --> The Pyruvate concentration did not change in timestep 31
# --> The Acetaldehyde concentration did not change in timestep 31
# --> The Acetyl-CoA concentration did not change in timestep 31
# --> The Succinate concentration did not change in timestep 31
# --> The Acetyl phosphate concentration did not change in timestep 31
# --> The 2-Oxoglutarate concentration did not change in timestep 31
# --> The AMP C10H12N5O7P concentration did not change in timestep 31
# --> The Coenzyme A concentration did not change in timestep 31
# --> The Ethanol concentration did not change in timestep 31
# --> The Formate concentration did not change in timestep 31
# --> The D-Fructose concentration did not change in timestep 31
# timestep 32
#
# objective value for timestep 32:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 32
# --> The D-Lactate concentration did not change in timestep 32
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 32
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 32
# --> The Acetate concentration did not change in timestep 32
# --> The Pyruvate concentration did not change in timestep 32
# --> The Acetaldehyde concentration did not change in timestep 32
# --> The Acetyl-CoA concentration did not change in timestep 32
# --> The Succinate concentration did not change in timestep 32
# --> The Acetyl phosphate concentration did not change in timestep 32
# --> The 2-Oxoglutarate concentration did not change in timestep 32
# --> The AMP C10H12N5O7P concentration did not change in timestep 32
# --> The Coenzyme A concentration did not change in timestep 32
# --> The Ethanol concentration did not change in timestep 32
# --> The Formate concentration did not change in timestep 32
# --> The D-Fructose concentration did not change in timestep 32
# timestep 33
#
# objective value for timestep 33:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 33
# --> The D-Lactate concentration did not change in timestep 33
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 33
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 33
# --> The Acetate concentration did not change in timestep 33
# --> The Pyruvate concentration did not change in timestep 33
# --> The Acetaldehyde concentration did not change in timestep 33
# --> The Acetyl-CoA concentration did not change in timestep 33
# --> The Succinate concentration did not change in timestep 33
# --> The Acetyl phosphate concentration did not change in timestep 33
# --> The 2-Oxoglutarate concentration did not change in timestep 33
# --> The AMP C10H12N5O7P concentration did not change in timestep 33
# --> The Coenzyme A concentration did not change in timestep 33
# --> The Ethanol concentration did not change in timestep 33
# --> The Formate concentration did not change in timestep 33
# --> The D-Fructose concentration did not change in timestep 33
# timestep 34
#
# objective value for timestep 34:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 34
# --> The D-Lactate concentration did not change in timestep 34
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 34
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 34
# --> The Acetate concentration did not change in timestep 34
# --> The Pyruvate concentration did not change in timestep 34
# --> The Acetaldehyde concentration did not change in timestep 34
# --> The Acetyl-CoA concentration did not change in timestep 34
# --> The Succinate concentration did not change in timestep 34
# --> The Acetyl phosphate concentration did not change in timestep 34
# --> The 2-Oxoglutarate concentration did not change in timestep 34
# --> The AMP C10H12N5O7P concentration did not change in timestep 34
# --> The Coenzyme A concentration did not change in timestep 34
# --> The Ethanol concentration did not change in timestep 34
# --> The Formate concentration did not change in timestep 34
# --> The D-Fructose concentration did not change in timestep 34
# timestep 35
#
# objective value for timestep 35:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 35
# --> The D-Lactate concentration did not change in timestep 35
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 35
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 35
# --> The Acetate concentration did not change in timestep 35
# --> The Pyruvate concentration did not change in timestep 35
# --> The Acetaldehyde concentration did not change in timestep 35
# --> The Acetyl-CoA concentration did not change in timestep 35
# --> The Succinate concentration did not change in timestep 35
# --> The Acetyl phosphate concentration did not change in timestep 35
# --> The 2-Oxoglutarate concentration did not change in timestep 35
# --> The AMP C10H12N5O7P concentration did not change in timestep 35
# --> The Coenzyme A concentration did not change in timestep 35
# --> The Ethanol concentration did not change in timestep 35
# --> The Formate concentration did not change in timestep 35
# --> The D-Fructose concentration did not change in timestep 35
# timestep 36
#
# objective value for timestep 36:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 36
# --> The D-Lactate concentration did not change in timestep 36
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 36
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 36
# --> The Acetate concentration did not change in timestep 36
# --> The Pyruvate concentration did not change in timestep 36
# --> The Acetaldehyde concentration did not change in timestep 36
# --> The Acetyl-CoA concentration did not change in timestep 36
# --> The Succinate concentration did not change in timestep 36
# --> The Acetyl phosphate concentration did not change in timestep 36
# --> The 2-Oxoglutarate concentration did not change in timestep 36
# --> The AMP C10H12N5O7P concentration did not change in timestep 36
# --> The Coenzyme A concentration did not change in timestep 36
# --> The Ethanol concentration did not change in timestep 36
# --> The Formate concentration did not change in timestep 36
# --> The D-Fructose concentration did not change in timestep 36
# timestep 37
#
# objective value for timestep 37:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 37
# --> The D-Lactate concentration did not change in timestep 37
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 37
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 37
# --> The Acetate concentration did not change in timestep 37
# --> The Pyruvate concentration did not change in timestep 37
# --> The Acetaldehyde concentration did not change in timestep 37
# --> The Acetyl-CoA concentration did not change in timestep 37
# --> The Succinate concentration did not change in timestep 37
# --> The Acetyl phosphate concentration did not change in timestep 37
# --> The 2-Oxoglutarate concentration did not change in timestep 37
# --> The AMP C10H12N5O7P concentration did not change in timestep 37
# --> The Coenzyme A concentration did not change in timestep 37
# --> The Ethanol concentration did not change in timestep 37
# --> The Formate concentration did not change in timestep 37
# --> The D-Fructose concentration did not change in timestep 37
# timestep 38
#
# objective value for timestep 38:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 38
# --> The D-Lactate concentration did not change in timestep 38
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 38
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 38
# --> The Acetate concentration did not change in timestep 38
# --> The Pyruvate concentration did not change in timestep 38
# --> The Acetaldehyde concentration did not change in timestep 38
# --> The Acetyl-CoA concentration did not change in timestep 38
# --> The Succinate concentration did not change in timestep 38
# --> The Acetyl phosphate concentration did not change in timestep 38
# --> The 2-Oxoglutarate concentration did not change in timestep 38
# --> The AMP C10H12N5O7P concentration did not change in timestep 38
# --> The Coenzyme A concentration did not change in timestep 38
# --> The Ethanol concentration did not change in timestep 38
# --> The Formate concentration did not change in timestep 38
# --> The D-Fructose concentration did not change in timestep 38
# timestep 39
#
# objective value for timestep 39:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 39
# --> The D-Lactate concentration did not change in timestep 39
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 39
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 39
# --> The Acetate concentration did not change in timestep 39
# --> The Pyruvate concentration did not change in timestep 39
# --> The Acetaldehyde concentration did not change in timestep 39
# --> The Acetyl-CoA concentration did not change in timestep 39
# --> The Succinate concentration did not change in timestep 39
# --> The Acetyl phosphate concentration did not change in timestep 39
# --> The 2-Oxoglutarate concentration did not change in timestep 39
# --> The AMP C10H12N5O7P concentration did not change in timestep 39
# --> The Coenzyme A concentration did not change in timestep 39
# --> The Ethanol concentration did not change in timestep 39
# --> The Formate concentration did not change in timestep 39
# --> The D-Fructose concentration did not change in timestep 39
# timestep 40
#
# objective value for timestep 40:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 40
# --> The D-Lactate concentration did not change in timestep 40
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 40
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 40
# --> The Acetate concentration did not change in timestep 40
# --> The Pyruvate concentration did not change in timestep 40
# --> The Acetaldehyde concentration did not change in timestep 40
# --> The Acetyl-CoA concentration did not change in timestep 40
# --> The Succinate concentration did not change in timestep 40
# --> The Acetyl phosphate concentration did not change in timestep 40
# --> The 2-Oxoglutarate concentration did not change in timestep 40
# --> The AMP C10H12N5O7P concentration did not change in timestep 40
# --> The Coenzyme A concentration did not change in timestep 40
# --> The Ethanol concentration did not change in timestep 40
# --> The Formate concentration did not change in timestep 40
# --> The D-Fructose concentration did not change in timestep 40
# timestep 41
#
# objective value for timestep 41:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 41
# --> The D-Lactate concentration did not change in timestep 41
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 41
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 41
# --> The Acetate concentration did not change in timestep 41
# --> The Pyruvate concentration did not change in timestep 41
# --> The Acetaldehyde concentration did not change in timestep 41
# --> The Acetyl-CoA concentration did not change in timestep 41
# --> The Succinate concentration did not change in timestep 41
# --> The Acetyl phosphate concentration did not change in timestep 41
# --> The 2-Oxoglutarate concentration did not change in timestep 41
# --> The AMP C10H12N5O7P concentration did not change in timestep 41
# --> The Coenzyme A concentration did not change in timestep 41
# --> The Ethanol concentration did not change in timestep 41
# --> The Formate concentration did not change in timestep 41
# --> The D-Fructose concentration did not change in timestep 41
# timestep 42
#
# objective value for timestep 42:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 42
# --> The D-Lactate concentration did not change in timestep 42
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 42
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 42
# --> The Acetate concentration did not change in timestep 42
# --> The Pyruvate concentration did not change in timestep 42
# --> The Acetaldehyde concentration did not change in timestep 42
# --> The Acetyl-CoA concentration did not change in timestep 42
# --> The Succinate concentration did not change in timestep 42
# --> The Acetyl phosphate concentration did not change in timestep 42
# --> The 2-Oxoglutarate concentration did not change in timestep 42
# --> The AMP C10H12N5O7P concentration did not change in timestep 42
# --> The Coenzyme A concentration did not change in timestep 42
# --> The Ethanol concentration did not change in timestep 42
# --> The Formate concentration did not change in timestep 42
# --> The D-Fructose concentration did not change in timestep 42
# timestep 43
#
# objective value for timestep 43:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 43
# --> The D-Lactate concentration did not change in timestep 43
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 43
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 43
# --> The Acetate concentration did not change in timestep 43
# --> The Pyruvate concentration did not change in timestep 43
# --> The Acetaldehyde concentration did not change in timestep 43
# --> The Acetyl-CoA concentration did not change in timestep 43
# ...
# --> The Succinate concentration did not change in timestep 93
# --> The Acetyl phosphate concentration did not change in timestep 93
# --> The 2-Oxoglutarate concentration did not change in timestep 93
# --> The AMP C10H12N5O7P concentration did not change in timestep 93
# --> The Coenzyme A concentration did not change in timestep 93
# --> The Ethanol concentration did not change in timestep 93
# --> The Formate concentration did not change in timestep 93
# --> The D-Fructose concentration did not change in timestep 93
# timestep 94
#
# objective value for timestep 94:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 94
# --> The D-Lactate concentration did not change in timestep 94
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 94
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 94
# --> The Acetate concentration did not change in timestep 94
# --> The Pyruvate concentration did not change in timestep 94
# --> The Acetaldehyde concentration did not change in timestep 94
# --> The Acetyl-CoA concentration did not change in timestep 94
# --> The Succinate concentration did not change in timestep 94
# --> The Acetyl phosphate concentration did not change in timestep 94
# --> The 2-Oxoglutarate concentration did not change in timestep 94
# --> The AMP C10H12N5O7P concentration did not change in timestep 94
# --> The Coenzyme A concentration did not change in timestep 94
# --> The Ethanol concentration did not change in timestep 94
# --> The Formate concentration did not change in timestep 94
# --> The D-Fructose concentration did not change in timestep 94
# timestep 95
#
# objective value for timestep 95:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 95
# --> The D-Lactate concentration did not change in timestep 95
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 95
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 95
# --> The Acetate concentration did not change in timestep 95
# --> The Pyruvate concentration did not change in timestep 95
# --> The Acetaldehyde concentration did not change in timestep 95
# --> The Acetyl-CoA concentration did not change in timestep 95
# --> The Succinate concentration did not change in timestep 95
# --> The Acetyl phosphate concentration did not change in timestep 95
# --> The 2-Oxoglutarate concentration did not change in timestep 95
# --> The AMP C10H12N5O7P concentration did not change in timestep 95
# --> The Coenzyme A concentration did not change in timestep 95
# --> The Ethanol concentration did not change in timestep 95
# --> The Formate concentration did not change in timestep 95
# --> The D-Fructose concentration did not change in timestep 95
# timestep 96
#
# objective value for timestep 96:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 96
# --> The D-Lactate concentration did not change in timestep 96
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 96
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 96
# --> The Acetate concentration did not change in timestep 96
# --> The Pyruvate concentration did not change in timestep 96
# --> The Acetaldehyde concentration did not change in timestep 96
# --> The Acetyl-CoA concentration did not change in timestep 96
# --> The Succinate concentration did not change in timestep 96
# --> The Acetyl phosphate concentration did not change in timestep 96
# --> The 2-Oxoglutarate concentration did not change in timestep 96
# --> The AMP C10H12N5O7P concentration did not change in timestep 96
# --> The Coenzyme A concentration did not change in timestep 96
# --> The Ethanol concentration did not change in timestep 96
# --> The Formate concentration did not change in timestep 96
# --> The D-Fructose concentration did not change in timestep 96
# timestep 97
#
# objective value for timestep 97:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 97
# --> The D-Lactate concentration did not change in timestep 97
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 97
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 97
# --> The Acetate concentration did not change in timestep 97
# --> The Pyruvate concentration did not change in timestep 97
# --> The Acetaldehyde concentration did not change in timestep 97
# --> The Acetyl-CoA concentration did not change in timestep 97
# --> The Succinate concentration did not change in timestep 97
# --> The Acetyl phosphate concentration did not change in timestep 97
# --> The 2-Oxoglutarate concentration did not change in timestep 97
# --> The AMP C10H12N5O7P concentration did not change in timestep 97
# --> The Coenzyme A concentration did not change in timestep 97
# --> The Ethanol concentration did not change in timestep 97
# --> The Formate concentration did not change in timestep 97
# --> The D-Fructose concentration did not change in timestep 97
# timestep 98
#
# objective value for timestep 98:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 98
# --> The D-Lactate concentration did not change in timestep 98
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 98
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 98
# --> The Acetate concentration did not change in timestep 98
# --> The Pyruvate concentration did not change in timestep 98
# --> The Acetaldehyde concentration did not change in timestep 98
# --> The Acetyl-CoA concentration did not change in timestep 98
# --> The Succinate concentration did not change in timestep 98
# --> The Acetyl phosphate concentration did not change in timestep 98
# --> The 2-Oxoglutarate concentration did not change in timestep 98
# --> The AMP C10H12N5O7P concentration did not change in timestep 98
# --> The Coenzyme A concentration did not change in timestep 98
# --> The Ethanol concentration did not change in timestep 98
# --> The Formate concentration did not change in timestep 98
# --> The D-Fructose concentration did not change in timestep 98
# timestep 99
#
# objective value for timestep 99:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 99
# --> The D-Lactate concentration did not change in timestep 99
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 99
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 99
# --> The Acetate concentration did not change in timestep 99
# --> The Pyruvate concentration did not change in timestep 99
# --> The Acetaldehyde concentration did not change in timestep 99
# --> The Acetyl-CoA concentration did not change in timestep 99
# --> The Succinate concentration did not change in timestep 99
# --> The Acetyl phosphate concentration did not change in timestep 99
# --> The 2-Oxoglutarate concentration did not change in timestep 99
# --> The AMP C10H12N5O7P concentration did not change in timestep 99
# --> The Coenzyme A concentration did not change in timestep 99
# --> The Ethanol concentration did not change in timestep 99
# --> The Formate concentration did not change in timestep 99
# --> The D-Fructose concentration did not change in timestep 99
# timestep 100
#
# objective value for timestep 100:  0.8739215069684301
#
#
# --> The Glyoxylate concentration did not change in timestep 100
# --> The D-Lactate concentration did not change in timestep 100
# --> The Nicotinamide adenine dinucleotide concentration did not change in timestep 100
# --> The Nicotinamide adenine dinucleotide - reduced concentration did not change in timestep 100
# --> The Acetate concentration did not change in timestep 100
# --> The Pyruvate concentration did not change in timestep 100
# --> The Acetaldehyde concentration did not change in timestep 100
# --> The Acetyl-CoA concentration did not change in timestep 100
# --> The Succinate concentration did not change in timestep 100
# --> The Acetyl phosphate concentration did not change in timestep 100
# --> The 2-Oxoglutarate concentration did not change in timestep 100
# --> The AMP C10H12N5O7P concentration did not change in timestep 100
# --> The Coenzyme A concentration did not change in timestep 100
# --> The Ethanol concentration did not change in timestep 100
# --> The Formate concentration did not change in timestep 100
# --> The D-Fructose concentration did not change in timestep 100
# ==================================================
#                2 (min) 4 (min) 6 (min) 8 (min) 10 (min) 12 (min) 14 (min) 16 (min) 18 (min) 20 (min) 22 (min) 24 (min) 26 (min) 28 (min) 30 (min) 32 (min) 34 (min) 36 (min) 38 (min) 40 (min) 42 (min) 44 (min) 46 (min) 48 (min) 50 (min) 52 (min) 54 (min) 56 (min) 58 (min) 60 (min) 62 (min) 64 (min) 66 (min) 68 (min) 70 (min) 72 (min) 74 (min) 76 (min) 78 (min) 80 (min) 82 (min) 84 (min) 86 (min) 88 (min) 90 (min) 92 (min) 94 (min) 96 (min) 98 (min) 100 (min) 102 (min) 104 (min) 106 (min) 108 (min) 110 (min) 112 (min) 114 (min) 116 (min) 118 (min) 120 (min) 122 (min) 124 (min) 126 (min) 128 (min) 130 (min) 132 (min) 134 (min) 136 (min) 138 (min) 140 (min) 142 (min) 144 (min) 146 (min) 148 (min) 150 (min) 152 (min) 154 (min) 156 (min) 158 (min) 160 (min) 162 (min) 164 (min) 166 (min) 168 (min) 170 (min) 172 (min) 174 (min) 176 (min) 178 (min) 180 (min) 182 (min) 184 (min) 186 (min) 188 (min) 190 (min) 192 (min) 194 (min) 196 (min) 198 (min) 200 (min)
# enzymes
# acetate kinase     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# (               2 (min) 4 (min) 6 (min) 8 (min) 10 (min) 12 (min) 14 (min)  \
#  enzymes
#  acetate kinase     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#                 16 (min) 18 (min) 20 (min)  ... 182 (min) 184 (min) 186 (min)  \
#  enzymes                                    ...
#  acetate kinase      NaN      NaN      NaN  ...       NaN       NaN       NaN
#
#                 188 (min) 190 (min) 192 (min) 194 (min) 196 (min) 198 (min)  \
#  enzymes
#  acetate kinase       NaN       NaN       NaN       NaN       NaN       NaN
#
#                 200 (min)
#  enzymes
#  acetate kinase       NaN
#
#  [1 rows x 100 columns],
#  [<Solution 0.874 at 0x2a1fa920688>,
#   <Solution 0.874 at 0x2a1fa98c588>,
#   <Solution 0.874 at 0x2a1fa991e88>,
#   <Solution 0.874 at 0x2a1fa6cb548>,
#   <Solution 0.874 at 0x2a1fa9921c8>,
#   <Solution 0.874 at 0x2a1fa992ac8>,
#   <Solution 0.874 at 0x2a1fc5c3948>,
#   <Solution 0.874 at 0x2a1fc5c38c8>,
#   <Solution 0.874 at 0x2a1fc5c5448>,
#   <Solution 0.874 at 0x2a1fc5c5948>,
#   <Solution 0.874 at 0x2a1fc5c5e08>,
#   <Solution 0.874 at 0x2a1fc5c1e08>,
#   <Solution 0.874 at 0x2a1fc5c1688>,
#   <Solution 0.874 at 0x2a1fc685448>,
#   <Solution 0.874 at 0x2a1fc685148>,
#   <Solution 0.874 at 0x2a1fc685a08>,
#   <Solution 0.874 at 0x2a1fc57b688>,
#   <Solution 0.874 at 0x2a1fc6cc848>,
#   <Solution 0.874 at 0x2a1fc692248>,
#   <Solution 0.874 at 0x2a1fc68cb48>,
#   <Solution 0.874 at 0x2a1fc6be588>,
#   <Solution 0.874 at 0x2a1fc6d0e08>,
#   <Solution 0.874 at 0x2a1fc64bac8>,
#   <Solution 0.874 at 0x2a1fc64bb08>,
#   <Solution 0.874 at 0x2a1faf28308>,
#   <Solution 0.874 at 0x2a1fc66a948>,
#   <Solution 0.874 at 0x2a1fc667a08>,
#   <Solution 0.874 at 0x2a1fc667748>,
#   <Solution 0.874 at 0x2a1fc655048>,
#   <Solution 0.874 at 0x2a1f9522888>,
#   <Solution 0.874 at 0x2a1fc658688>,
#   <Solution 0.874 at 0x2a1fc5f2848>,
#   <Solution 0.874 at 0x2a1fc683b88>,
#   <Solution 0.874 at 0x2a1f95b4d08>,
#   <Solution 0.874 at 0x2a1fc64fcc8>,
#   <Solution 0.874 at 0x2a1fc645c48>,
#   <Solution 0.874 at 0x2a1fc5e4188>,
#   <Solution 0.874 at 0x2a1fc6cc8c8>,
#   <Solution 0.874 at 0x2a1fc645848>,
#   <Solution 0.874 at 0x2a1fc5e1408>,
#   <Solution 0.874 at 0x2a1fc6e6fc8>,
#   <Solution 0.874 at 0x2a1fc5df688>,
#   <Solution 0.874 at 0x2a1fc5dd2c8>,
#   <Solution 0.874 at 0x2a1fc5dd648>,
#   <Solution 0.874 at 0x2a1fc5dc488>,
#   <Solution 0.874 at 0x2a1fc6ae788>,
#   <Solution 0.874 at 0x2a1fc6ae288>,
#   <Solution 0.874 at 0x2a1fc5d89c8>,
#   <Solution 0.874 at 0x2a1fc5d8488>,
#   <Solution 0.874 at 0x2a1faf1ce08>,
#   <Solution 0.874 at 0x2a1fc5d7708>,
#   <Solution 0.874 at 0x2a1fc5d7348>,
#   <Solution 0.874 at 0x2a1fc5d6b08>,
#   <Solution 0.874 at 0x2a1fae0f688>,
#   <Solution 0.874 at 0x2a1fabfe4c8>,
#   <Solution 0.874 at 0x2a1fae16948>,
#   <Solution 0.874 at 0x2a1fae48248>,
#   <Solution 0.874 at 0x2a1fc5d4f48>,
#   <Solution 0.874 at 0x2a1fc5d3208>,
#   <Solution 0.874 at 0x2a1fa86f9c8>,
#   <Solution 0.874 at 0x2a1faf22648>,
#   <Solution 0.874 at 0x2a1fc68ed08>,
#   <Solution 0.874 at 0x2a1fc5d2208>,
#   <Solution 0.874 at 0x2a1fc5d28c8>,
#   <Solution 0.874 at 0x2a1fc694b88>,
#   <Solution 0.874 at 0x2a1fc6c4108>,
#   <Solution 0.874 at 0x2a1fc5d0548>,
#   <Solution 0.874 at 0x2a1fc5ced08>,
#   <Solution 0.874 at 0x2a1fc5ce648>,
#   <Solution 0.874 at 0x2a1fc6ac0c8>,
#   <Solution 0.874 at 0x2a1faf27248>,
#   <Solution 0.874 at 0x2a1fc5cd4c8>,
#   <Solution 0.874 at 0x2a1fae481c8>,
#   <Solution 0.874 at 0x2a1fc5cd108>,
#   <Solution 0.874 at 0x2a1fc5ccec8>,
#   <Solution 0.874 at 0x2a1fae45948>,
#   <Solution 0.874 at 0x2a1fae45e48>,
#   <Solution 0.874 at 0x2a1fc659f88>,
#   <Solution 0.874 at 0x2a1fc6638c8>,
#   <Solution 0.874 at 0x2a1fadfe8c8>,
#   <Solution 0.874 at 0x2a1fc65f048>,
#   <Solution 0.874 at 0x2a1fc6aa548>,
#   <Solution 0.874 at 0x2a1fc5ca048>,
#   <Solution 0.874 at 0x2a1fc5c8fc8>,
#   <Solution 0.874 at 0x2a1fc5c8948>,
#   <Solution 0.874 at 0x2a1fc674c88>,
#   <Solution 0.874 at 0x2a1fc680208>,
#   <Solution 0.874 at 0x2a1fc671a08>,
#   <Solution 0.874 at 0x2a1fc5c74c8>,
#   <Solution 0.874 at 0x2a1fc5c7508>,
#   <Solution 0.874 at 0x2a1fc5c2148>,
#   <Solution 0.874 at 0x2a1fadf3e48>,
#   <Solution 0.874 at 0x2a1faf1ea48>,
#   <Solution 0.874 at 0x2a1fad1cbc8>,
#   <Solution 0.874 at 0x2a1fae0ce48>,
#   <Solution 0.874 at 0x2a1fae06fc8>,
#   <Solution 0.874 at 0x2a1faaec988>,
#   <Solution 0.874 at 0x2a1faaecf88>,
#   <Solution 0.874 at 0x2a1faaecd88>,
#   <Solution 0.874 at 0x2a1fc09bc08>])

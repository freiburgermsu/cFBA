# %%
import json, os
# %run ../../dfbapy/dfba.py

# define inital conditions
kinetics_path = os.path.join('..','..','..','BiGG_SABIO','bigg_models','scraping-test_Ecoli-3','model_kinetics.json')

model_path = '../e_coli_core.xml'
temp_c = 25
ph = 7

dfba = dFBA(
    model_path,
    verbose = False,
    printing = True,
    jupyter = True
)
# %time dfba.simulate(kinetics_path, total_time = 200, timestep = 50, included_metabolites = ['L-Malate', 'Phosphate', 'Acetate', 'Glyceraldehyde 3-phosphate', 'D-Fructose 6-phosphate'])
dfba.export('SABIO_fba')
# Out:
# The N-alpha-(benzyloxycarbonyl)-N-omega-(D,L-1,2-dithiolane-3-pentanoyl)-L-lysine metabolite is not in the BiGG model
# The Enzyme metabolite is not in the BiGG model
# The dTTP metabolite is not in the BiGG model
# The 2-Methylpropanal metabolite is not in the BiGG model
# The Enzyme metabolite is not in the BiGG model
# The Fructose 1,6-bisphosphate metabolite is not in the BiGG model
# The Sedoheptulose 1-phosphate metabolite is not in the BiGG model
# The Nicotinamide hypoxanthine dinucleotide phosphate metabolite is not in the BiGG model
# The D-Ribose 5-phosphate metabolite is not in the BiGG model
# The NADH metabolite is not in the BiGG model
# The Enzyme metabolite is not in the BiGG model
# The NADPH metabolite is not in the BiGG model
# The Iodonitrotetrazolium metabolite is not in the BiGG model
# The NADPH metabolite is not in the BiGG model
# The Iodonitrotetrazolium metabolite is not in the BiGG model
# The Hydroxylamine metabolite is not in the BiGG model
# ...
